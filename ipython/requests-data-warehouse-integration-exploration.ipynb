# %%
from pyspark.sql import SparkSession
from pandas import set_option

set_option('display.max.columns', None)

spark = (
    SparkSession
    .builder
    .config('spark.driver.memory', '4g')
    .config('spark.executor.memory', '2g')
    .getOrCreate()
)

spark.conf.set('spark.sql.adaptive.enabled', True)
spark.conf.set('spark.sql.session.timeZone', 'UTC')

# %%
import os

PATH = '/tmp/requests'
BRONZE = os.path.join(PATH, 'bronze')
SILVER = os.path.join(PATH, 'silver')

# %% [markdown]
# ## Bronze

# %% [markdown]
# ### Work Items

# %%
path = os.path.join(BRONZE, 'WorkItems')

# life cycle
# truncate(transdate)
# to_date('ownedsince', 'lastupdated')
workItems = spark.read.parquet(path)

print(f'workItems contains {workItems.count():,} records')
workItems.limit(5).toPandas()
# Out:
# workItems contains 2,652,986 records
#    lcnum  statenum  contentnum  wfcontenttype               transdate  \
# 0    125       298    11190595              3 2018-02-11 07:07:08.553
# 1    125       298    11190596              3 2018-02-11 07:07:08.630
# 2    125       298    11190597              3 2018-02-11 07:07:08.710
# 3    125       298    11190598              3 2018-02-11 07:07:08.787
# 4    125       298    11190599              3 2018-02-11 07:07:08.880
#
#    priority  versionid  ownernum  ownedstatus ownedsince lastupdated  flags  \
# 0         0          0         0            0 1964-01-01  1964-01-01      0
# 1         0          0         0            0 1964-01-01  1964-01-01      0
# 2         0          0         0            0 1964-01-01  1964-01-01      0
# 3         0          0         0            0 1964-01-01  1964-01-01      0
# 4         0          0         0            0 1964-01-01  1964-01-01      0
#
#    contentclassnum
# 0             1184
# 1             1184
# 2             1184
# 3             1184
# 4             1184

# %%
from pyspark.sql.functions import desc

(
    workItems
    .groupBy('contentnum')
    .count()
    .orderBy(desc('count'))
    .show(5)
)
# Out:
# +----------+-----+
# |contentnum|count|
# +----------+-----+
# |  38042788|    3|
# |  48645558|    3|
# |  43469386|    3|
# |  43148707|    3|
# |  48538073|    3|
# +----------+-----+
# only showing top 5 rows

# %%
# priority...flags all same value
(
    workItems
    .where('contentnum = 40252908')
    .orderBy('transdate')
    # .select('lcnum', 'statenum', 'contentnum', 'transdate')
    .toPandas()
    # .to_csv('/tmp/workitemlc', index=False)
)
# Out:
#    lcnum  statenum  contentnum  wfcontenttype               transdate  \
# 0    160       446    40252908              3 2022-03-25 09:27:27.057
# 1    152       419    40252908              3 2022-06-09 09:24:47.243
#
#    priority  versionid  ownernum  ownedstatus ownedsince lastupdated  flags  \
# 0         0          0         0            0 1964-01-01  1964-01-01      0
# 1         0          0         0            0 1964-01-01  1964-01-01      0
#
#    contentclassnum
# 0             1225
# 1             1225

# %% [markdown]
# ```sql
# SELECT lcnum, statenum, contentnum, transdate FROM workitemlc WHERE contentnum = 40252908 ORDER BY transdate
# ```

# %%
# from pyspark.sql.functions import min, max

# (
#     workItems
#     .groupBy('contentnum')
#     .agg(
#         min('transdate').cast('long').alias('minimum'),
#         max('transdate').cast('long').alias('maximum')
#     )
#     .selectExpr(
#         'contentnum',
#         'maximum - minimum as seconds'
#     )
#     .orderBy(desc('seconds'))
#     .show(5)
# )

# %%
# from pyspark.sql import Window
# from pyspark.sql.functions import desc, rank

# window = Window.partitionBy('contentnum').orderBy(desc('transdate'))

# (
#     workItems
#     .withColumn('_rank', rank().over(window))
#     .where('lcnum = 160')
#     .where('_rank > 1')
#     .limit(5)
#     .toPandas()
# )

# %%
# # 160 always last or second to last
# (
#     workItems
#     .withColumn('_rank', rank().over(window))
#     .where('lcnum = 160')
#     .groupBy('_rank')
#     .count()
#     .show()
# )

# %%
# # when rank = 2, statenum almost always 446
# (
#     workItems
#     .withColumn('_rank', row_number().over(window))
#     .where('lcnum = 160')
#     .groupBy('_rank', 'statenum')
#     .count()
#     .orderBy(desc('_rank'), 'statenum')
#     .show()
# )

# %%
# from pyspark.sql.functions import date_trunc

# (
#     workItems
#     .withColumn('transdate', date_trunc('second', 'transdate'))
#     .select('contentnum', 'transdate')
#     .dropDuplicates()
#     .count()
# ) - workItems.count()

# %% [markdown]
# ### Objects

# %%
path = os.path.join(BRONZE, 'Objects')

# truncate(createddate)
objects = spark.read.parquet(path)

print(f'objects contains {objects.count():,} records')
(
    objects
    .select(
        'objectid',
        'activestatus' # = 0
    )
    .limit(5)
    .toPandas()
)
# Out:
# objects contains 47,827,882 records
#    objectid  activestatus
# 0    193512             1
# 1    193513             0
# 2    193514             0
# 3    193515             0
# 4    193516             0

# %%
(
    objects
    .groupBy('activestatus')
    .count()
    .toPandas()
)
# Out:
#    activestatus     count
# 0             1   2775623
# 1             2   4090960
# 2             0  40961299

# %%
# %%time
# object only has one state
(
    objects
    .groupBy('objectid')
    .count()
    .where('count > 1')
    .count()
)
# Out:
# CPU times: user 8.18 ms, sys: 5 ms, total: 13.2 ms
# Wall time: 45.2 s
# 0

# %%
# roughly 1,000 records missing from objects table
(
    requests
    .join(
        objects,
        on='objectid',
        how='left_semi'
    )
    .count()
)
# Out:
# 539270

# %%
# requests.count()

(
    objects
    .join(
        requests,
        on='objectid',
        how='left_semi'        
    )
    .groupBy('activestatus')
    .count()
    .show()
)
# Out:
# +------------+------+
# |activestatus| count|
# +------------+------+
# |           0|539270|
# +------------+------+

# %%
(
    objects
    .join(
        workItems.where('lcnum = 160'),
        on=workItems['contentnum'] == objects['objectid'],
        how='left_semi'        
    )
    .groupBy('activestatus')
    .count()
    .show()
)
# Out:
# +------------+-----+
# |activestatus|count|
# +------------+-----+
# |           1|   32|
# |           0|52589|
# +------------+-----+

# %%
(
    requests
    .join(
        objects.where('activestatus = 1')
        .join(
            workItems.where('lcnum = 160'),
            on=workItems['contentnum'] == objects['objectid'],
            how='left_semi'        
        ),
        on='objectid',
        how='inner'
    )
    .count()
)
# Out:
# 0

# %% [markdown]
# ### Jobs

# %%
path = os.path.join(BRONZE, 'Jobs')

# JobNo
# ManagerPodName
# ManagerID
# SupervisorID
jobs = spark.read.parquet(path)

print(f'jobs contains {jobs.count():,} records')
(
    jobs
    .select(
        'JobNo',
        'ManagerPodName',
        'ManagerID',
        'SupervisorID'
    )
    .where('ManagerPodName is not null')
    .limit(5)
    .toPandas()
)
# Out:
# jobs contains 1,400 records
#    JobNo ManagerPodName  ManagerID  SupervisorID
# 0   2929           Blue     194740        194740
# 1   3067           Gold     194747        194730
# 2   2761           Blue     194740        194749
# 3   2916           Blue     194740        194749
# 4   2927           Blue     194740        194749

# %%
jobs.groupBy('ManagerPodName').count().show()
# Out:
# +--------------+-----+
# |ManagerPodName|count|
# +--------------+-----+
# |        Orange|   28|
# |          null| 1059|
# |        Purple|   18|
# |          Blue|   59|
# |          Gold|   76|
# |         Black|   10|
# |           Red|   97|
# |          Grey|   53|
# +--------------+-----+

# %% [markdown]
# ### States

# %%
path = os.path.join(BRONZE, 'States')

states = spark.read.parquet(path)

print(f'states contains {states.count():,} records')
(
    states
    .selectExpr(
        'statenum as queue'
    )
    .limit(5)
    .toPandas()
)
# Out:
# states contains 310 records
#    queue
# 0    185
# 1    186
# 2    187
# 3    188
# 4    189

# %% [markdown]
# ### Requests

# %%
# path = os.path.join(BRONZE, 'StatementRequests')
path = '/Users/curtispassorelli/Desktop/data/requests/bronze/StatementRequests'

requests = spark.read.parquet(path)

print(f'requests contains {requests.count():,} records')

# TODO: convert decimal to double
(
    requests
#     .select(
#         'JobNo',
#         'CustomerName',
#         'VendorNo',
#         'WNC',
#         'StatementWNC',
#         'VendorGroupName',
#         'Volume',
#         'VolumeTier',
#         'VolumeLast12',
#         'RequestDate',
#         'ReferenceNumber',
#         'Status',
#         'RequestMethod',
#         'RequestType',
#         'Contact',
#         'RequesterFullName',
#         'LastActivityDate',
#         'LastStatementReceivedDate',
#         'CallsheetNo',
#         'ObjectID',
#         'CallerStatus',
#         'WebsiteVendor',
#         'WNCSpecialHandling',
#         'NeedLeadVendor'
#     )
    .limit(5)
    .toPandas()
)
# Out:
# requests contains 540,462 records
#     JobNo                         CustomerName VendorNo  WNC  StatementWNC  \
# 0     NaN                                 None     None  NaN           NaN
# 1  3427.0  New Hanover Regional Medical Center    16845  NaN           NaN
# 2  3427.0  New Hanover Regional Medical Center    16845  NaN           NaN
# 3  3427.0  New Hanover Regional Medical Center    16845  NaN           NaN
# 4  3427.0  New Hanover Regional Medical Center    16845  NaN           NaN
#
#                VendorGroupName Volume VolumeTier VolumeLast12 RequestDate  \
# 0                         None   None       None         None         NaT
# 1  A M COFFEE DISTRIBUTORS LLC   0.00          B     0.000000  2020-07-24
# 2  A M COFFEE DISTRIBUTORS LLC   0.00          B     0.000000  2020-07-31
# 3  A M COFFEE DISTRIBUTORS LLC   0.00          B     0.000000  2021-01-19
# 4  A M COFFEE DISTRIBUTORS LLC   0.00          B     0.000000  2021-08-19
#
#    ReferenceNumber      Status RequestMethod RequestType  \
# 0              NaN         New          None      Caller
# 1        1285660.0  Superceded     MassEmail        None
# 2        1285660.0  Superceded     MassEmail      Mass 1
# 3        1285660.0  Superceded     MassEmail      Caller
# 4        1285660.0  Superceded     MassEmail      Mass 1
#
#                   Contact RequesterFullName LastActivityDate  \
# 0                    None              None              NaT
# 1  amcoffeedist@gmail.com  Jessica Rinehart       2020-07-24
# 2  amcoffeedist@gmail.com  Jessica Rinehart       2020-07-31
# 3  amcoffeedist@gmail.com  Jessica Rinehart       2020-07-31
# 4  amcoffeedist@gmail.com       Cindy Allen       2021-08-23
#
#   LastStatementReceivedDate CallsheetNo  ObjectID               CallerStatus  \
# 0                       NaT        None  47597380                       None
# 1                       NaT    C-338914  26681846                       None
# 2                       NaT    C-338914  26819776                       None
# 3                       NaT    C-338914  30690711  Sent Authorization Letter
# 4                       NaT    C-338914  36365526  Sent Authorization Letter
#
#    WebsiteVendor  WNCSpecialHandling  NeedLeadVendor
# 0            NaN                 NaN             NaN
# 1            NaN                 NaN             NaN
# 2            NaN                 NaN             NaN
# 3            NaN                 NaN             NaN
# 4            NaN                 NaN             NaN

# %%
# anti: 487,758
# semi: 52,589
(
    requests
    .join(
        workItems,
        on=requests['ObjectID'] == workItems['contentnum'],
        how='left_semi'
    )
    .count()
)
# Out:
# 52589

# %%
path = os.path.join(BRONZE, 'Employees')

employees = spark.read.parquet(path)
employees.createOrReplaceTempView('EMPLOYEES')

print(f'employees contains {employees.count():,} records')
(
    employees
#     .selectExpr(
#         'statenum as queue'
#     )
    .limit(5)
    .toPandas()
)
# Out:
# employees contains 468 records
#        ID                     Email           FullName         Phone  \
# 0  194728      aprins@spendmend.com         Andi Prins  616-257-6362
# 1  194729    bvangoor@spendmend.com        Bob VanGoor  616-257-6306
# 2  194730  ckretowicz@spendmend.com  Colleen Kretowicz  616-257-6398
# 3  194731      callen@spendmend.com        Cindy Allen  616-257-6377
# 4  194732   dhutchins@spendmend.com       Dan Hutchins  616-257-6317
#
#     PrimaryRoleName PodName     ManagerName  ManagerObjectID
# 0  Audit Supervisor    Gold  Travis Wheeler           194747
# 1  Audit Supervisor     Red    Dan Hutchins           194732
# 2  Audit Supervisor    Gold  Travis Wheeler           194747
# 3       WNC Auditor    None            None         33876443
# 4     Audit Manager     Red    Dan Hutchins           194739

# %%
# employees.where('ManagerObjectID is null').limit(20).toPandas()
# jobs.where('ManagerID = SupervisorID').count() # 18
# jobs.where('ManagerID != SupervisorID').count() # 381; almost all different


# jobs.where('ManagerID is not null').count() # 412
# jobs.where('SupervisorID is not null').count() # 400

# jobs.where('ManagerID is not null and SupervisorID is not null').count() # 399

# employees.where('ManagerName is not null').count() 95
# employees.where('ManagerObjectID is not null').count() # 349
# Out:
# 349

# %%
# query = """
# WITH
# organization (ID, FullName, ManagerObjectID) AS (
# SELECT
#     ID,
#     FullName,
#     ManagerObjectID
# FROM
#     EMPLOYEES
# WHERE
#     ManagerObjectID IS NULL
# UNION ALL
# SELECT
#     EMPLOYEES.ID,
#     EMPLOYEES.FullName,
#     EMPLOYEES.ManagerObjectID
# FROM
#     EMPLOYEES
#         INNER JOIN
#             organization ON
#                 organization.ID = EMPLOYEES.ManagerObjectID
# )
# SELECT * FROM organization
# """

# (
#     spark
#     .sql(query)
#     .limit(5)
#     .toPandas()
# )

# %%
(
    requests
    .join(
        jobs
            .select(
                'JobNo',
                'ManagerPodName',
                'ManagerID',
                'SupervisorID'
            ),
        on='JobNo',
        how='inner'
    )
    .join(
        employees,
        on=requests['RequesterFullName'] == employees['FullName'],
        how='inner'
    )
    .limit(5)
    .toPandas()
)
# Out:
#    JobNo                         CustomerName VendorNo  WNC  StatementWNC  \
# 0   3427  New Hanover Regional Medical Center    16845  NaN           NaN
# 1   3427  New Hanover Regional Medical Center    16845  NaN           NaN
# 2   3427  New Hanover Regional Medical Center    16845  NaN           NaN
# 3   3427  New Hanover Regional Medical Center    16845  NaN           NaN
# 4   3427  New Hanover Regional Medical Center    16845  NaN           NaN
#
#                VendorGroupName Volume VolumeTier VolumeLast12 RequestDate  \
# 0  A M COFFEE DISTRIBUTORS LLC   0.00          B     0.000000  2020-07-24
# 1  A M COFFEE DISTRIBUTORS LLC   0.00          B     0.000000  2020-07-31
# 2  A M COFFEE DISTRIBUTORS LLC   0.00          B     0.000000  2021-01-19
# 3  A M COFFEE DISTRIBUTORS LLC   0.00          B     0.000000  2021-08-19
# 4  A M COFFEE DISTRIBUTORS LLC   0.00          B     0.000000  2021-09-03
#
#    ReferenceNumber      Status RequestMethod RequestType  \
# 0          1285660  Superceded     MassEmail        None
# 1          1285660  Superceded     MassEmail      Mass 1
# 2          1285660  Superceded     MassEmail      Caller
# 3          1285660  Superceded     MassEmail      Mass 1
# 4          1285660  No Receipt     MassEmail      Caller
#
#                   Contact RequesterFullName LastActivityDate  \
# 0  amcoffeedist@gmail.com  Jessica Rinehart       2020-07-24
# 1  amcoffeedist@gmail.com  Jessica Rinehart       2020-07-31
# 2  amcoffeedist@gmail.com  Jessica Rinehart       2020-07-31
# 3  amcoffeedist@gmail.com       Cindy Allen       2021-08-23
# 4  amcoffeedist@gmail.com       Cindy Allen       2021-08-23
#
#   LastStatementReceivedDate CallsheetNo  ObjectID               CallerStatus  \
# 0                       NaT    C-338914  26681846                       None
# 1                       NaT    C-338914  26819776                       None
# 2                       NaT    C-338914  30690711  Sent Authorization Letter
# 3                       NaT    C-338914  36365526  Sent Authorization Letter
# 4                       NaT    C-338914  36846273  Sent Authorization Letter
#
#    WebsiteVendor  WNCSpecialHandling  NeedLeadVendor ManagerPodName  \
# 0            NaN                 NaN             NaN           Gold
# 1            NaN                 NaN             NaN           Gold
# 2            NaN                 NaN             NaN           Gold
# 3            NaN                 NaN             NaN           Gold
# 4            NaN                 NaN             NaN           Gold
#
#    ManagerID  SupervisorID       ID                    Email  \
# 0     194747        194728  8398642  jrinehart@spendmend.com
# 1     194747        194728  8398642  jrinehart@spendmend.com
# 2     194747        194728  8398642  jrinehart@spendmend.com
# 3     194747        194728   194731     callen@spendmend.com
# 4     194747        194728   194731     callen@spendmend.com
#
#            FullName           Phone  PrimaryRoleName PodName ManagerName  \
# 0  Jessica Rinehart  (616) 257-6373  Statement Admin    None        None
# 1  Jessica Rinehart  (616) 257-6373  Statement Admin    None        None
# 2  Jessica Rinehart  (616) 257-6373  Statement Admin    None        None
# 3       Cindy Allen    616-257-6377      WNC Auditor    None        None
# 4       Cindy Allen    616-257-6377      WNC Auditor    None        None
#
#    ManagerObjectID
# 0           194731
# 1           194731
# 2           194731
# 3         33876443
# 4         33876443

# %% [markdown]
# ### Activities

# %%
path = os.path.join(BRONZE, 'StatementRequestActivityRecords')

activities = spark.read.parquet(path)
print(f'jobs contains {activities.count():,} records')
activities.limit(5).toPandas()
# Out:
# jobs contains 2,358,664 records
#    ObjectID             CreatedDate  ReferenceNumber  \
# 0  28785475 2020-11-02 11:41:33.170          1279250
# 1  28785637 2020-11-02 11:47:27.003          1279250
# 2  28786094 2020-11-02 11:52:58.307          1279250
# 3  28838136 2020-11-04 17:47:58.533          1287154
# 4  28838138 2020-11-04 17:48:02.617          1225130
#
#               CustomerVendorName  JobNumber                          JobName  \
# 0                          ULINE       3412  Carolinas Shared Service - 3412
# 1                          ULINE       3412  Carolinas Shared Service - 3412
# 2                          ULINE       3412  Carolinas Shared Service - 3412
# 3             BIOCOMPOSITES INC.       3435       The Christ Hospital - 3435
# 4  BONA FIDE COMMERCIAL SERVICES       3177                 UC Health - 3177
#
#     ContactType ActivityUser Outcome ActivityType  VendorContactObjectID  \
# 0          Call      ASIBLEY    None         None                    NaN
# 1         Email      ASIBLEY    None         None                    NaN
# 2  Client Email      ASIBLEY    None         None                    NaN
# 3          None   bwilliams1    None         None                    NaN
# 4          None      jdagher    None         None                    NaN
#
#    StatementRequestObjectID
# 0                  25422522
# 1                  25422522
# 2                  25422522
# 3                  27781594
# 4                  25860124

# %% [markdown]
# ### Statements

# %%
path = os.path.join(BRONZE, 'Statements')

# StatementDate
statements = spark.read.parquet(path)
print(f'statements contains {statements.count():,} records')
statements.limit(5).toPandas()
# Out:
# statements contains 490,410 records
#    ReferenceNumber StatementDate  ObjectID  \
# 0          1224005    2019-08-14  20513258
# 1          1229524    2019-08-14  20513265
# 2          1247505    2019-08-14  20513268
# 3          1248087    2019-08-14  20513273
# 4          1224005    2019-08-14  20513254
#
#                                       EmailMessageID             CreatedDate  \
# 0  00000000F643DA057DBD124B829A30CFCF400C1507002B... 2019-08-14 11:18:01.353
# 1  00000000F643DA057DBD124B829A30CFCF400C1507002B... 2019-08-14 11:18:26.637
# 2  00000000F643DA057DBD124B829A30CFCF400C1507002B... 2019-08-14 11:19:08.073
# 3  00000000F643DA057DBD124B829A30CFCF400C1507002B... 2019-08-14 11:19:43.393
# 4  00000000F643DA057DBD124B829A30CFCF400C1507002B... 2019-08-14 11:17:48.653
#
#    SRARObjectId
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %% [markdown]
# ### Notes

# %%
path = os.path.join(BRONZE, 'Notes')

# STID = ReferenceNumber
# STNDescription
# STNAdded
notes = spark.read.parquet(path)
print(f'notes contains {notes.count():,} records')
notes.limit(5).toPandas()
# Out:
# notes contains 7,800,558 records
#    STNID  STID  STLID                                     STNDescription  \
# 0     48  1694    NaN  Follow up date changed from 9/12/2002 to 09/05...
# 1     50  1726    NaN                                               TEst
# 2     51  1726    NaN  Status changed from Need Senior to Call to Sen...
# 3     52  1726    NaN  Status changed from Sent Authorization Letter ...
# 4     53  1726    NaN  Follow up date changed from 9/11/2002 to 09/06...
#
#              STNAdded         STNAddedby          STNUpdated STNUpdatedby  \
# 0 2002-09-23 11:48:34  Frederick Clingen 2002-09-23 11:48:34         None
# 1 2002-09-23 14:24:04  Frederick Clingen 2002-09-23 14:24:04         None
# 2 2002-09-23 14:24:08  Frederick Clingen 2002-09-23 14:24:08         None
# 3 2002-09-23 14:24:24  Frederick Clingen 2002-09-23 14:24:24         None
# 4 2002-09-23 14:39:16  Frederick Clingen 2002-09-23 14:39:16         None
#
#    PTNoteID
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
from pyspark.sql.functions import lower

# with out there superior visior permission
# (
#     notes
#     .where(lower('STNDescription').contains('release'))
#     .select('STNDescription')
#     .where(~lower('STNDescription').contains('re-release'))
#     .show(truncate=False)
#     # .count()
# )

# %% [markdown]
# ### Projects

# %%
path = os.path.join(BRONZE, 'Projects')

# JobNo
# ProjectType
# Status
projects = spark.read.parquet(path)
print(f'projects contains {projects.count():,} records')
projects.limit(5).toPandas()
# Out:
# projects contains 3,937 records
#   ProjectNo            Name  JobNo  Status  PrimaryAuditorID  \
# 0    P-1311     3011 - Data   3011  Closed               NaN
# 1    P-1313  3011 - Returns   3011  Closed               NaN
# 2    P-1314     3010 - Data   3010  Closed               NaN
# 3    P-1315    3010 - Dupes   3010  Closed               NaN
# 4    P-1317     3008 - Data   3008  Closed               NaN
#
#    SecondaryAuditorID  StartDate    EndDate ProjectType  \
# 0                 NaN 2018-04-26        NaT        Data
# 1                 NaN 2018-04-26        NaT     Returns
# 2                 NaN 2018-04-26        NaT        Data
# 3                 NaN 2018-04-26 2018-12-06       Dupes
# 4                 NaN 2018-04-26 2018-05-31        Data
#
#   VendorPotentialThreshold WorkingItemThreshold  ImagingAccess  \
# 0                  1000.00               250.00              1
# 1                  1000.00               250.00              1
# 2                  1000.00               250.00              1
# 3                  1000.00               250.00              1
# 4                  1000.00               250.00              1
#
#    PercentComplete  AvailableInPortal PortalFriendlyName  RollingOOSInterval  \
# 0                0                  1               None                 NaN
# 1                0                  1               None                 NaN
# 2                0                  1               None                 NaN
# 3                0                  1               None                 NaN
# 4                0                  1               None                 NaN
#
#    UsesModernWorkingItems AgedOpenCreditDate AgedOpenCreditMinimum  \
# 0                     NaN                NaT                  None
# 1                     NaN                NaT                  None
# 2                     NaN                NaT                  None
# 3                     NaN                NaT                  None
# 4                     NaN                NaT                  None
#
#    DebitsProject  KillOnClosed     ServiceType      ServiceLine
# 0            NaN           NaN  Recovery Audit  Profit Recovery
# 1            NaN           NaN  Recovery Audit  Profit Recovery
# 2            NaN           NaN  Recovery Audit  Profit Recovery
# 3            NaN           NaN  Recovery Audit  Profit Recovery
# 4            NaN           NaN  Recovery Audit  Profit Recovery

# %%
# (
#     projects
#     .groupBy('JobNo')
#     .count()
#     .orderBy(desc('count'))
#     .show()
# )

# %%
(
    projects
    .groupBy('Status')
    .count()
    .orderBy(desc('count'))
    .show()
)
# Out:
# +------+-----+
# |Status|count|
# +------+-----+
# |Closed| 2533|
# |  Open| 1086|
# |  Prep|  288|
# |  Pull|   19|
# |Review|   11|
# +------+-----+

# %%
from pyspark.sql.functions import approx_count_distinct

(
    projects
    # .groupBy('JobNo', 'StartDate')
    # .agg(approx_count_distinct('Status').alias('count'))
    .groupBy('JobNo', 'ProjectType')
    # .groupBy('JobNo')
    # .agg(approx_count_distinct('StartDate').alias('count'))
    .count()
    .where('count > 1')
    .orderBy(desc('count'))
    .show(25, truncate=False)
)
# Out:
# +-----+-----------------------------+-----+
# |JobNo|ProjectType                  |count|
# +-----+-----------------------------+-----+
# |2873 |GPO Pricing                  |2    |
# |2879 |GPO Pricing                  |2    |
# |3278 |Local Contracts              |2    |
# |3427 |In Scope Credits Loaded      |2    |
# |2939 |Spike                        |2    |
# |3292 |Dupes                        |2    |
# |3179 |Sales and Use Tax Review     |2    |
# |2868 |Pricing Top 100              |2    |
# |3010 |Multi Acct Recon             |2    |
# |3415 |Missing Invoices             |2    |
# |3406 |Local Contracts              |2    |
# |2938 |Uncashed Checks              |2    |
# |3175 |Returns                      |2    |
# |2896 |Statement Phone and Account #|2    |
# |2929 |OOS                          |2    |
# +-----+-----------------------------+-----+

# %%
# appears Closed usually has an EndDate
# name is JobNo + ProjectType
projects.where('JobNo = 2896').orderBy('StartDate', 'EndDate').toPandas()
# Out:
#    ProjectNo                                  Name  JobNo  Status  \
# 0       P-36                           2896 - Data   2896  Closed
# 1       P-43                2896 - Pricing Top 100   2896  Closed
# 2       P-42                  2896 - Cash Discount   2896  Closed
# 3       P-40                          2896 - Spike   2896  Closed
# 4       P-41                    2896 - GPO Pricing   2896  Closed
# 5       P-37                          2896 - Dupes   2896  Closed
# 6       P-38                        2896 - Returns   2896  Closed
# 7      P-395  2896 - Statement Phone and Account #   2896  Closed
# 8      P-416  2896 - Statement Phone and Account #   2896  Closed
# 9       P-39                       2896 - AP vs PO   2896  Closed
# 10      P-45             2896 - Capital PO Project   2896  Closed
# 11      P-44                2896 - Local Contracts   2896  Closed
#
#     PrimaryAuditorID  SecondaryAuditorID  StartDate    EndDate  \
# 0             194734                 NaN        NaT        NaT
# 1             194730            194730.0        NaT        NaT
# 2             194731            194731.0 2016-08-04 2016-10-14
# 3             194731            194731.0 2016-08-04 2016-10-19
# 4             194730            194730.0 2016-08-04 2017-01-27
# 5             194730            194730.0 2016-10-07 2018-02-23
# 6             194730            194730.0 2016-10-10 2017-01-24
# 7             194728            194728.0 2016-10-31 2016-11-01
# 8             194728           1137359.0 2016-11-29 2017-01-23
# 9             194730            194730.0 2017-01-24 2017-03-19
# 10            194730            194730.0 2017-01-24 2017-03-19
# 11            194730            194730.0 2017-01-27 2017-03-19
#
#                       ProjectType VendorPotentialThreshold  \
# 0                            Data                     None
# 1                 Pricing Top 100                     None
# 2                   Cash Discount                     None
# 3                           Spike                     None
# 4                     GPO Pricing                     None
# 5                           Dupes                     None
# 6                         Returns                     None
# 7   Statement Phone and Account #                     None
# 8   Statement Phone and Account #                     None
# 9                        AP vs PO                     None
# 10             Capital PO Project                     None
# 11                Local Contracts                     None
#
#    WorkingItemThreshold  ImagingAccess  PercentComplete  AvailableInPortal  \
# 0                  None            NaN              NaN                1.0
# 1                  None            NaN              NaN                NaN
# 2                  None            NaN              NaN                NaN
# 3                  None            NaN              NaN                NaN
# 4                  None            NaN              NaN                NaN
# 5                  None            1.0             75.0                1.0
# 6                  None            NaN              NaN                NaN
# 7                  None            NaN              NaN                NaN
# 8                  None            NaN              NaN                NaN
# 9                  None            NaN              NaN                NaN
# 10                 None            NaN              NaN                NaN
# 11                 None            NaN              NaN                NaN
#
#    PortalFriendlyName  RollingOOSInterval  UsesModernWorkingItems  \
# 0                Data                 NaN                     NaN
# 1                None                 NaN                     NaN
# 2                None                 NaN                     NaN
# 3                None                 NaN                     NaN
# 4                None                 NaN                     NaN
# 5        2896 - Dupes                 NaN                     NaN
# 6                None                 NaN                     NaN
# 7                None                 NaN                     NaN
# 8                None                 NaN                     NaN
# 9                None                 NaN                     NaN
# 10               None                 NaN                     NaN
# 11               None                 NaN                     NaN
#
#    AgedOpenCreditDate AgedOpenCreditMinimum  DebitsProject  KillOnClosed  \
# 0                 NaT                  None            NaN           NaN
# 1                 NaT                  None            NaN           NaN
# 2                 NaT                  None            NaN           NaN
# 3                 NaT                  None            NaN           NaN
# 4                 NaT                  None            NaN           NaN
# 5                 NaT                  None            NaN           NaN
# 6                 NaT                  None            NaN           NaN
# 7                 NaT                  None            NaN           NaN
# 8                 NaT                  None            NaN           NaN
# 9                 NaT                  None            NaN           NaN
# 10                NaT                  None            NaN           NaN
# 11                NaT                  None            NaN           NaN
#
#        ServiceType      ServiceLine
# 0   Recovery Audit  Profit Recovery
# 1   Recovery Audit  Profit Recovery
# 2   Recovery Audit  Profit Recovery
# 3   Recovery Audit  Profit Recovery
# 4   Recovery Audit  Profit Recovery
# 5   Recovery Audit  Profit Recovery
# 6   Recovery Audit  Profit Recovery
# 7   Recovery Audit  Profit Recovery
# 8   Recovery Audit  Profit Recovery
# 9   Recovery Audit  Profit Recovery
# 10  Recovery Audit  Profit Recovery
# 11  Recovery Audit  Profit Recovery

# %% [markdown]
# ## Silver

# %% [markdown]
# ### Requests

# %%
# %%time
from pyspark.sql.functions import col, lit, lower

column = when(lower('Contact').contains('@'), lower('Contact'))

path = os.path.join(SILVER, 'requests')


(
    spark
    .read
    .parquet(os.path.join(BRONZE, 'StatementRequests'))
    .withColumn('Contact', column)
    .withColumnRenamed('RequesterFullName', 'EMPLOYEE_NAME')
#     .join(
#         employees
#             .select('EMPLOYEE_ID', 'EMPLOYEE_NAME'),
#         on='EMPLOYEE_NAME',
#         how='inner'
#     )
    .selectExpr(
        'ObjectID as REQUEST_ID',
        # 'EMPLOYEE_ID',
        'cast(RequestDate as date) as REQUEST_DATE',
        'Status as REQUEST_STATUS',
        'RequestMethod as REQUEST_METHOD',
        'RequestType as REQUEST_TYPE',
        'cast(LastActivityDate as date) as LAST_ACTIVITY_DATE',
        'cast(LastStatementReceivedDate as date) as LAST_RECEIVED_DATE',
        'cast(WNC as boolean) as WILL_NOT_COMPLY'
    )
    .write
    .mode('overwrite')
    .parquet(path)
)


requests = spark.read.parquet(path)
requests.createOrReplaceTempView('requests')
# display(requests)
# requests.limit(5).toPandas()
# Out:
# CPU times: user 8.25 ms, sys: 2.97 ms, total: 11.2 ms
# Wall time: 1.61 s

# %%
path = os.path.join(SILVER, 'requests')
print(f'requests contains {requests.count():,} records')
requests = spark.read.parquet(path)
requests.createOrReplaceTempView('requests')
# display(requests)
requests.limit(5).toPandas()
# Out:
# requests contains 539,270 records
#    REQUEST_ID REQUEST_DATE   REQUEST_STATUS REQUEST_METHOD REQUEST_TYPE  \
# 0    25422373   2020-04-30   Fully Received      MassEmail         None
# 1    25422392   2020-04-30   Fully Received      MassEmail         None
# 2    25422433   2020-04-30   Fully Received      MassEmail         None
# 3    25422445   2020-04-30   Fully Received      MassEmail         None
# 4    25422454   2020-04-30  Partial Receipt      MassEmail         None
#
#   LAST_ACTIVITY_DATE LAST_RECEIVED_DATE WILL_NOT_COMPLY
# 0         2020-04-30         2020-05-03           False
# 1         2020-04-30               None            None
# 2         2020-04-30         2020-05-03            None
# 3         2020-04-30         2020-05-03            None
# 4         2020-04-30         2020-05-03            None

# %% [markdown]
# ### Activities

# %%
from pyspark.sql import Window
from pyspark.sql.functions import col, create_map, date_trunc, desc, lit, row_number, when

path = os.path.join(SILVER, 'activities')

column = when(col('ContactType') != 'N/A', col('ContactType'))

mapping = create_map(
    lit('Called Vendor'), lit('CALL'),
    lit('Note Only'), lit('NOTE'),
    lit('Emailed Vendor'), lit('EMAIL'),
    lit('Received Call / Email'), lit('RESPONSE')
)

# window = Window.partitionBy('EMPLOYEE_ID', 'REFERENCE_ID').orderBy(desc('ACTIVITY_DATE'))

(
    spark
    .read
    .parquet(os.path.join(BRONZE, 'StatementRequestActivityRecords'))
    .withColumn('ActivityType', mapping[col('ActivityType')])
    .withColumn('ContactType', column)
    .withColumn('CreatedDate', date_trunc('second', 'CreatedDate'))
    .withColumnRenamed('ActivityUser', 'EMPLOYEE_NAME')
#     .join(
#         employees
#             .select('EMPLOYEE_ID', 'EMPLOYEE_NAME'),
#         on='EMPLOYEE_NAME',
#         # how='inner'
#         how='left'
#     )
    .selectExpr(
        'ObjectID as ACTIVITY_ID',
        'ReferenceNumber as REFERENCE_ID',
        'VendorContactObjectID as CONTACT_ID',
        'StatementRequestObjectID as REQUEST_ID',
        # 'EMPLOYEE_ID',
        'CreatedDate as ACTIVITY_DATE',
        'ActivityType as ACTIVITY',
        'JobNumber as JOB_NUMBER',
        'JobName as JOB_NAME',
        'CustomerVendorName as VENDOR_NAME',
        'cast(ReferenceNumber as string) as REFERENCE_NUMBER',
        'Outcome as OUTCOME'
    )
    # .withColumn('EMPLOYEE_REFERENCE_RANK', row_number().over(window))
    .write
    .mode('overwrite')
    .parquet(path)
)


activities = spark.read.parquet(path)
activities.createOrReplaceTempView('activities')
# display(activities)
# activities.limit(5).toPandas()
# Out:
# DataFrame[ACTIVITY_ID: int, REFERENCE_ID: int, CONTACT_ID: int, REQUEST_ID: int, ACTIVITY_DATE: timestamp, ACTIVITY: string, JOB_NUMBER: int, JOB_NAME: string, VENDOR_NAME: string, REFERENCE_NUMBER: string, OUTCOME: string]

# %%
path = os.path.join(SILVER, 'activities')
activities = spark.read.parquet(path)
activities.createOrReplaceTempView('activities')
print(f'activities contains {activities.count():,} records')
# display(activities)
activities.limit(5).toPandas()
# Out:
# activities contains 2,358,664 records
#    ACTIVITY_ID  REFERENCE_ID  CONTACT_ID  REQUEST_ID       ACTIVITY_DATE  \
# 0     28785475       1279250         NaN    25422522 2020-11-02 06:41:33
# 1     28785637       1279250         NaN    25422522 2020-11-02 06:47:27
# 2     28786094       1279250         NaN    25422522 2020-11-02 06:52:58
# 3     28838136       1287154         NaN    27781594 2020-11-04 12:47:58
# 4     28838138       1225130         NaN    25860124 2020-11-04 12:48:02
#
#   ACTIVITY  JOB_NUMBER                         JOB_NAME  \
# 0     None        3412  Carolinas Shared Service - 3412
# 1     None        3412  Carolinas Shared Service - 3412
# 2     None        3412  Carolinas Shared Service - 3412
# 3     None        3435       The Christ Hospital - 3435
# 4     None        3177                 UC Health - 3177
#
#                      VENDOR_NAME REFERENCE_NUMBER OUTCOME
# 0                          ULINE          1279250    None
# 1                          ULINE          1279250    None
# 2                          ULINE          1279250    None
# 3             BIOCOMPOSITES INC.          1287154    None
# 4  BONA FIDE COMMERCIAL SERVICES          1225130    None

# %% [markdown]
# ### Statements

# %%
path = os.path.join(SILVER, 'statements')

( 
    spark
    .read
    .parquet(os.path.join(BRONZE, 'Statements'))
    .withColumn('CreatedDate', date_trunc('second', 'CreatedDate'))
    .selectExpr(
        'ReferenceNumber as REFERENCE_ID',
        'abs(xxhash64(EmailMessageID)) as EMAIL_ID',
        'CreatedDate as STATEMENT_DATE',
    )
#     .join(
#         activities,
#         on='REFERENCE_ID',
#         how='left_semi'
#     )
    .write
    .mode('overwrite')
    .parquet(path)
)


statements = spark.read.parquet(path)
statements.createOrReplaceTempView('statements')
# display(statements)
# statements.limit(5).toPandas()

# %%
path = os.path.join(SILVER, 'statements')
statements = spark.read.parquet(path)
print(f'statements contains {statements.count():,} records')
statements.createOrReplaceTempView('statements')
# display(statements)
statements.limit(5).toPandas()
# Out:
# statements contains 490,410 records
#    REFERENCE_ID             EMAIL_ID      STATEMENT_DATE
# 0       1224005  8479961916226615153 2019-08-14 07:18:01
# 1       1229524  3064791696795579927 2019-08-14 07:18:26
# 2       1247505  4632731259035230330 2019-08-14 07:19:08
# 3       1248087  5187333399925037547 2019-08-14 07:19:43
# 4       1224005  8479961916226615153 2019-08-14 07:17:48

# %% [markdown]
# ### Life Cycle

# %%
# %%time
# from pyspark.sql import Window
# from pyspark.sql.functions import date_trunc, desc, rank

# window = Window.partitionBy('contentnum').orderBy(desc('transdate'))

path = os.path.join(SILVER, 'processes')

# life cycle
# primary key (contentnum, lcnum)
(
    workItems
    .withColumn('transdate', date_trunc('second', 'transdate'))
    .select('contentnum', 'lcnum', 'statenum', 'transdate')
    .dropDuplicates()
    .withColumn('_rank', row_number().over(window))
    .join(
        objects
        .selectExpr('objectid as contentnum', 'activestatus'),
        on='contentnum',
        how='inner'
    )
    .selectExpr(
        'contentnum as LIFE_CYCLE_ID',
        'lcnum as LIFE_CYCLE_CODE',
        'statenum as STATE_CODE',
        'activestatus as ACTIVE_STATUS_CODE',
        'transdate as TRANSACTION_DATE',
        '_rank as LIFE_CYCLE_RANK'
    )
    .write
    .mode('overwrite')
    .parquet(path)
# )

processes = spark.read.parquet(path)
processes.limit(5).toPandas()
# Out:
#    LIFE_CYCLE_ID  LIFE_CYCLE_CODE  STATE_CODE  ACTIVE_STATUS_CODE  \
# 0         194780              126         208                   0
# 1         194784              126         208                   0
# 2         291093              134         252                   0
# 3         315261              126         208                   0
# 4         404196              124         222                   1
#
#      TRANSACTION_DATE  LIFE_CYCLE_RANK
# 0 2018-08-06 09:40:25                1
# 1 2016-07-26 00:29:57                1
# 2 2021-05-08 01:35:53                1
# 3 2016-07-21 18:29:16                1
# 4 2016-07-19 14:49:20                1

# %% [markdown]
# ### Job

# %%
# %%time

path = os.path.join(SILVER, 'jobs')

(
    jobs
    .selectExpr(
        'JobNo as JOB_ID',
        'ManagerID as MANAGER_ID',
        'SupervisorID as SUPERVISOR_ID',
        'JobNo as JOB_NUMBER',
        'ManagerPodName as TEAM'
    )
    .limit(5)
    .toPandas()
)
# Out:
# CPU times: user 13.6 ms, sys: 2.86 ms, total: 16.4 ms
# Wall time: 144 ms
#    JOB_ID  MANAGER_ID  SUPERVISOR_ID  JOB_NUMBER  TEAM
# 0    2600         NaN            NaN        2600  None
# 1    3570         NaN            NaN        3570  None
# 2    3178         NaN            NaN        3178  None
# 3    3447         NaN            NaN        3447  None
# 4    3467         NaN            NaN        3467  None

# %%
spark.stop()
