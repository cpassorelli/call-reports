# %%
from pyspark.sql import SparkSession
from pandas import set_option

set_option('display.max.columns', None)

spark = SparkSession.builder.getOrCreate()

# %%
schema = """
next_page_token string,
page_size int,
total_records int,
from date,
to date,
call_logs array<
    struct<
        id: string,
        user_id: string,
        call_type: string,
        caller_number: string,
        caller_number_type: int,
        caller_name: string,
        caller_number_source: string,
        callee_number: string,
        caller_location: string,
        callee_number_type: int,
        callee_number_source: string,
        callee_location: string,
        callee_name: string,
        direction: string,
        duration: int,
        result: string,
        waiting_time: int,
        date_time: timestamp,
        path: string,
        has_recording: boolean,
        charge: string,
        voice_mail_id: string,
        has_voicemail: boolean,
        rate: string,
        call_id: string,
        owner: struct<
            type: string,
            id: string,
            name: string,
            extension_number: string
        >,
        caller_did_number: string,
        caller_country_code: string,
        caller_country_iso_code: string,
        callee_did_number: string,
        callee_country_code: string,
        callee_country_iso_code: string,
        answer_start_time: timestamp,
        call_end_time: timestamp
    >
>
"""

# %%
from pyspark.sql.types import ArrayType, StructType
from typing import List

def flatten(schema: StructType, prefix: str=None) -> List[str]:
    fields = list()

    for field in schema.fields:
        # check for Struct in each column
        name = prefix + '.' + field.name if prefix else field.name

        dtype = field.dataType

        # check if column is Array
        if isinstance(dtype, ArrayType):
            dtype = dtype.elementType

        # check if column is Struct
        if isinstance(dtype, StructType):
            # use nested dot `.` property
            # use function recursion
            fields += flatten(dtype, prefix=name)
        else:
            fields.append(name)

    return fields

# %%
from pyspark.sql.functions import explode

table = (
    spark
    .read
    .json(
        path='/tmp/phone-calls/AccountCallLogs.json',
        schema=schema,
        timestampFormat='yyyy-MM-ddTHH:mm:ssZ',
        mode='FAILFAST'
    )
    .withColumn('call_logs', explode('call_logs'))
)

# %%
columns = flatten(table.schema)

table.select(*columns).limit(5).toPandas()
# Out:
#                        next_page_token  page_size  total_records        from  \
# 0  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2        300           2530  2022-05-09
# 1  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2        300           2530  2022-05-09
# 2  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2        300           2530  2022-05-09
# 3  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2        300           2530  2022-05-09
# 4  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2        300           2530  2022-05-09
#
#            to                                    id                 user_id  \
# 0  2022-05-12  34bfc3eb-7180-4c83-b61b-345d084f72b1  d9JiQ8qqTcCh6bfVo2YIYw
# 1  2022-05-12  d3d79bc4-22cd-4936-9889-e10f815f45ba                    None
# 2  2022-05-12  2b8ca4c8-7adc-436a-a2b5-17b0aea69a20                    None
# 3  2022-05-12  fbc302fc-4082-4cb5-bb06-f99b603f3392  1avZmyzLRzu2AInJp75T1Q
# 4  2022-05-12  a0d06ee4-4472-40f6-a793-2edadca307f6  bkasEu6zRz2YKurlHXnIqw
#
#   call_type caller_number  caller_number_type      caller_name  \
# 0      pstn           255                   1  Nicole Thompson
# 1      voip  +16162081843                   2        Amerisave
# 2      voip  +15165658083                   2             None
# 3      voip  +12312656202                   2       2312656202
# 4      voip  +17022280222                   2      RR Partners
#
#   caller_number_source callee_number  caller_location  callee_number_type  \
# 0                 None  +18287377552             None                   2
# 1             internal           300             None                   1
# 2             internal           300  Garden City  NY                   1
# 3             internal           226             None                   1
# 4             internal           208             None                   1
#
#   callee_number_source callee_location             callee_name direction  \
# 0             internal     Newland, NC                    None  outbound
# 1                 None            None  Main Auto Receptionist   inbound
# 2                 None            None  Main Auto Receptionist   inbound
# 3                 None            None          Jessica Osborn   inbound
# 4                 None            None        Jessica Caggiano   inbound
#
#    duration       result  waiting_time           date_time              path  \
# 0         0  Call Cancel           NaN 2022-05-11 19:36:35              pstn
# 1         0    No Answer           NaN 2022-05-11 19:28:25  autoReceptionist
# 2         0    No Answer           NaN 2022-05-11 19:21:14  autoReceptionist
# 3         0    No Answer           NaN 2022-05-11 19:00:02              pstn
# 4         0    No Answer           NaN 2022-05-11 18:47:33              pstn
#
#    has_recording charge voice_mail_id  has_voicemail  rate  \
# 0          False   None          None          False  None
# 1          False   None          None          False  None
# 2          False   None          None          False  None
# 3          False   None          None          False  None
# 4          False   None          None          False  None
#
#                call_id              type                      id  \
# 0  7096626840318811841              user  d9JiQ8qqTcCh6bfVo2YIYw
# 1  7096624731490955678  autoReceptionist  fK99-uaJRnG8yW-b9B4-9g
# 2  7096622880360005894  autoReceptionist  fK99-uaJRnG8yW-b9B4-9g
# 3  7096617421447184140              user  1avZmyzLRzu2AInJp75T1Q
# 4  7096614200270916926              user  bkasEu6zRz2YKurlHXnIqw
#
#                      name  extension_number caller_did_number  \
# 0         Nicole Thompson               255      +16167290255
# 1  Main Auto Receptionist               300              None
# 2  Main Auto Receptionist               300              None
# 3          Jessica Osborn               226              None
# 4        Jessica Caggiano               208              None
#
#   caller_country_code caller_country_iso_code callee_did_number  \
# 0                   1                      US      +18287377552
# 1                   1                      US      +16162576300
# 2                   1                      US      +16162576300
# 3                   1                      US      +16162572026
# 4                   1                      US      +16162572008
#
#   callee_country_code callee_country_iso_code answer_start_time  \
# 0                   1                      US              None
# 1                   1                      US              None
# 2                   1                      US              None
# 3                   1                      US              None
# 4                   1                      US              None
#
#         call_end_time
# 0 2022-05-11 19:38:41
# 1                 NaT
# 2                 NaT
# 3                 NaT
# 4                 NaT

# %%
from pyspark.sql.functions import col

aliases = list()

for column in columns:
    tokens = column.split('.')
    if len(tokens) > 2:
        alias = '_'.join(tokens[1:])
    else:
        alias = tokens[-1]
    
    aliases.append(col(column).alias(alias))

# %%
table.select(*aliases).limit(5).toPandas()
# Out:
#                        next_page_token  page_size  total_records        from  \
# 0  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2        300           2530  2022-05-09
# 1  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2        300           2530  2022-05-09
# 2  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2        300           2530  2022-05-09
# 3  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2        300           2530  2022-05-09
# 4  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2        300           2530  2022-05-09
#
#            to                                    id                 user_id  \
# 0  2022-05-12  34bfc3eb-7180-4c83-b61b-345d084f72b1  d9JiQ8qqTcCh6bfVo2YIYw
# 1  2022-05-12  d3d79bc4-22cd-4936-9889-e10f815f45ba                    None
# 2  2022-05-12  2b8ca4c8-7adc-436a-a2b5-17b0aea69a20                    None
# 3  2022-05-12  fbc302fc-4082-4cb5-bb06-f99b603f3392  1avZmyzLRzu2AInJp75T1Q
# 4  2022-05-12  a0d06ee4-4472-40f6-a793-2edadca307f6  bkasEu6zRz2YKurlHXnIqw
#
#   call_type caller_number  caller_number_type      caller_name  \
# 0      pstn           255                   1  Nicole Thompson
# 1      voip  +16162081843                   2        Amerisave
# 2      voip  +15165658083                   2             None
# 3      voip  +12312656202                   2       2312656202
# 4      voip  +17022280222                   2      RR Partners
#
#   caller_number_source callee_number  caller_location  callee_number_type  \
# 0                 None  +18287377552             None                   2
# 1             internal           300             None                   1
# 2             internal           300  Garden City  NY                   1
# 3             internal           226             None                   1
# 4             internal           208             None                   1
#
#   callee_number_source callee_location             callee_name direction  \
# 0             internal     Newland, NC                    None  outbound
# 1                 None            None  Main Auto Receptionist   inbound
# 2                 None            None  Main Auto Receptionist   inbound
# 3                 None            None          Jessica Osborn   inbound
# 4                 None            None        Jessica Caggiano   inbound
#
#    duration       result  waiting_time           date_time              path  \
# 0         0  Call Cancel           NaN 2022-05-11 19:36:35              pstn
# 1         0    No Answer           NaN 2022-05-11 19:28:25  autoReceptionist
# 2         0    No Answer           NaN 2022-05-11 19:21:14  autoReceptionist
# 3         0    No Answer           NaN 2022-05-11 19:00:02              pstn
# 4         0    No Answer           NaN 2022-05-11 18:47:33              pstn
#
#    has_recording charge voice_mail_id  has_voicemail  rate  \
# 0          False   None          None          False  None
# 1          False   None          None          False  None
# 2          False   None          None          False  None
# 3          False   None          None          False  None
# 4          False   None          None          False  None
#
#                call_id        owner_type                owner_id  \
# 0  7096626840318811841              user  d9JiQ8qqTcCh6bfVo2YIYw
# 1  7096624731490955678  autoReceptionist  fK99-uaJRnG8yW-b9B4-9g
# 2  7096622880360005894  autoReceptionist  fK99-uaJRnG8yW-b9B4-9g
# 3  7096617421447184140              user  1avZmyzLRzu2AInJp75T1Q
# 4  7096614200270916926              user  bkasEu6zRz2YKurlHXnIqw
#
#                owner_name owner_extension_number caller_did_number  \
# 0         Nicole Thompson                    255      +16167290255
# 1  Main Auto Receptionist                    300              None
# 2  Main Auto Receptionist                    300              None
# 3          Jessica Osborn                    226              None
# 4        Jessica Caggiano                    208              None
#
#   caller_country_code caller_country_iso_code callee_did_number  \
# 0                   1                      US      +18287377552
# 1                   1                      US      +16162576300
# 2                   1                      US      +16162576300
# 3                   1                      US      +16162572026
# 4                   1                      US      +16162572008
#
#   callee_country_code callee_country_iso_code answer_start_time  \
# 0                   1                      US              None
# 1                   1                      US              None
# 2                   1                      US              None
# 3                   1                      US              None
# 4                   1                      US              None
#
#         call_end_time
# 0 2022-05-11 19:38:41
# 1                 NaT
# 2                 NaT
# 3                 NaT
# 4                 NaT

# %%
from pyspark.sql import DataFrame
from pyspark.sql.functions import lit, trim, when

def truncateStrings(dataFrame: DataFrame) -> DataFrame:
    for colName, dtype in dataFrame.dtypes:
        if dtype == 'string':
            column = trim(colName)
            case = when(column == '', lit(None).cast('string')).otherwise(column)
            dataFrame = dataFrame.withColumn(colName, case)

    return dataFrame

# %%
from pyspark.sql.functions import regexp_replace

table = (
    spark
    .read
    .json(
        path='/tmp/phone-calls/AccountCallLogs.json',
        schema=schema,
        timestampFormat='yyyy-MM-ddTHH:mm:ssZ',
        mode='FAILFAST'
    )
    .withColumn('call_logs', explode('call_logs'))
    .select(*aliases)
)


(
    truncateStrings(table)
    .withColumn('caller_location', regexp_replace('caller_location', r'\s+', ' '))
    .withColumn('charge', regexp_replace('charge', r'[^0-9\.]', '').cast('double'))
    .withColumn('rate', regexp_replace('rate', r'[^0-9\.]', '').cast('double'))
    .write
    .mode('overwrite')
    .parquet('/tmp/AccountCallLogs')
)


table = spark.read.parquet('/tmp/AccountCallLogs')
table.limit(5).toPandas()
# Out:
#                        next_page_token  page_size  total_records        from  \
# 0  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2        300           2530  2022-05-09
# 1  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2        300           2530  2022-05-09
# 2  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2        300           2530  2022-05-09
# 3  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2        300           2530  2022-05-09
# 4  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2        300           2530  2022-05-09
#
#            to                                    id                 user_id  \
# 0  2022-05-12  34bfc3eb-7180-4c83-b61b-345d084f72b1  d9JiQ8qqTcCh6bfVo2YIYw
# 1  2022-05-12  d3d79bc4-22cd-4936-9889-e10f815f45ba                    None
# 2  2022-05-12  2b8ca4c8-7adc-436a-a2b5-17b0aea69a20                    None
# 3  2022-05-12  fbc302fc-4082-4cb5-bb06-f99b603f3392  1avZmyzLRzu2AInJp75T1Q
# 4  2022-05-12  a0d06ee4-4472-40f6-a793-2edadca307f6  bkasEu6zRz2YKurlHXnIqw
#
#   call_type caller_number  caller_number_type      caller_name  \
# 0      pstn           255                   1  Nicole Thompson
# 1      voip  +16162081843                   2        Amerisave
# 2      voip  +15165658083                   2             None
# 3      voip  +12312656202                   2       2312656202
# 4      voip  +17022280222                   2      RR Partners
#
#   caller_number_source callee_number caller_location  callee_number_type  \
# 0                 None  +18287377552            None                   2
# 1             internal           300            None                   1
# 2             internal           300  Garden City NY                   1
# 3             internal           226            None                   1
# 4             internal           208            None                   1
#
#   callee_number_source callee_location             callee_name direction  \
# 0             internal     Newland, NC                    None  outbound
# 1                 None            None  Main Auto Receptionist   inbound
# 2                 None            None  Main Auto Receptionist   inbound
# 3                 None            None          Jessica Osborn   inbound
# 4                 None            None        Jessica Caggiano   inbound
#
#    duration       result  waiting_time           date_time              path  \
# 0         0  Call Cancel           NaN 2022-05-11 19:36:35              pstn
# 1         0    No Answer           NaN 2022-05-11 19:28:25  autoReceptionist
# 2         0    No Answer           NaN 2022-05-11 19:21:14  autoReceptionist
# 3         0    No Answer           NaN 2022-05-11 19:00:02              pstn
# 4         0    No Answer           NaN 2022-05-11 18:47:33              pstn
#
#    has_recording  charge voice_mail_id  has_voicemail  rate  \
# 0          False     NaN          None          False   NaN
# 1          False     NaN          None          False   NaN
# 2          False     NaN          None          False   NaN
# 3          False     NaN          None          False   NaN
# 4          False     NaN          None          False   NaN
#
#                call_id        owner_type                owner_id  \
# 0  7096626840318811841              user  d9JiQ8qqTcCh6bfVo2YIYw
# 1  7096624731490955678  autoReceptionist  fK99-uaJRnG8yW-b9B4-9g
# 2  7096622880360005894  autoReceptionist  fK99-uaJRnG8yW-b9B4-9g
# 3  7096617421447184140              user  1avZmyzLRzu2AInJp75T1Q
# 4  7096614200270916926              user  bkasEu6zRz2YKurlHXnIqw
#
#                owner_name owner_extension_number caller_did_number  \
# 0         Nicole Thompson                    255      +16167290255
# 1  Main Auto Receptionist                    300              None
# 2  Main Auto Receptionist                    300              None
# 3          Jessica Osborn                    226              None
# 4        Jessica Caggiano                    208              None
#
#   caller_country_code caller_country_iso_code callee_did_number  \
# 0                   1                      US      +18287377552
# 1                   1                      US      +16162576300
# 2                   1                      US      +16162576300
# 3                   1                      US      +16162572026
# 4                   1                      US      +16162572008
#
#   callee_country_code callee_country_iso_code answer_start_time  \
# 0                   1                      US               NaT
# 1                   1                      US               NaT
# 2                   1                      US               NaT
# 3                   1                      US               NaT
# 4                   1                      US               NaT
#
#         call_end_time
# 0 2022-05-11 19:38:41
# 1                 NaT
# 2                 NaT
# 3                 NaT
# 4                 NaT

# %% [markdown]
# ### Cardinality

# %%
[
    'call_type', # pstn, voip, international
    'caller_number_source', # null, international
    'caller_location', # null, ...
    'callee_number_source', # international, null
    'callee_location', # United States, null, ...
    'direction', # outbound, inbound
    'result', # Call connected, No Answer, Call Cancel, Rejected, Call failed
    'path', # pstn, autoReceptionist, extension, callQueue
    'owner_type', # user, autoReceptionist, callQueue
    'caller_country_code', # 1, ...
    'caller_country_iso_code', # US, null, GB, 001, CN, CR
    'callee_country_code', # 1, ...
    'callee_country_iso_code', # US, null, CA
]

# %%
from pyspark.sql.functions import desc

# table.where('answer_start_time is not null').select('answer_start_time').show()

# table.where('charge is not null').select('charge').show()

table.groupBy('callee_country_iso_code').count().orderBy(desc('count')).show()
# Out:
# +-----------------------+-----+
# |callee_country_iso_code|count|
# +-----------------------+-----+
# |                     US| 2471|
# |                   null|   47|
# |                     CA|    6|
# |                     IN|    2|
# |                     PK|    1|
# |                     CR|    1|
# |                     VI|    1|
# |                    001|    1|
# +-----------------------+-----+

# %% [markdown]
# ### Data Types

# %%
data = list()

for colName, dtype in table.select(*aliases).dtypes:
    if dtype != 'string':
        data.append((colName, dtype))
        
data
# Out:
# [('page_size', 'int'),
#  ('total_records', 'int'),
#  ('from', 'date'),
#  ('to', 'date'),
#  ('caller_number_type', 'bigint'),
#  ('callee_number_type', 'bigint'),
#  ('duration', 'bigint'),
#  ('waiting_time', 'bigint'),
#  ('date_time', 'timestamp'),
#  ('has_recording', 'boolean'),
#  ('has_voicemail', 'boolean'),
#  ('owner_extension_number', 'bigint'),
#  ('call_end_time', 'timestamp')]

# %%
(
    spark
    .read
    .json(
        path='/tmp/phone-calls/AccountCallLogs.json',
        primitivesAsString=True
    )
    .withColumn('call_logs', explode('call_logs'))
    .select(*aliases)
    .write
    .mode('overwrite')
    .parquet('/tmp/AccountCallLogs')
)

_table = spark.read.parquet('/tmp/AccountCallLogs')
_table.limit(5).toPandas()
# Out:
#                        next_page_token page_size total_records        from  \
# 0  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2       300          2530  2022-05-09
# 1  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2       300          2530  2022-05-09
# 2  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2       300          2530  2022-05-09
# 3  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2       300          2530  2022-05-09
# 4  MNI3JNNEPEyFrnxeuneeLaoRqOrnm1XNOQ2       300          2530  2022-05-09
#
#            to                                    id                 user_id  \
# 0  2022-05-12  34bfc3eb-7180-4c83-b61b-345d084f72b1  d9JiQ8qqTcCh6bfVo2YIYw
# 1  2022-05-12  d3d79bc4-22cd-4936-9889-e10f815f45ba                    None
# 2  2022-05-12  2b8ca4c8-7adc-436a-a2b5-17b0aea69a20                    None
# 3  2022-05-12  fbc302fc-4082-4cb5-bb06-f99b603f3392  1avZmyzLRzu2AInJp75T1Q
# 4  2022-05-12  a0d06ee4-4472-40f6-a793-2edadca307f6  bkasEu6zRz2YKurlHXnIqw
#
#   call_type caller_number caller_number_type      caller_name  \
# 0      pstn           255                  1  Nicole Thompson
# 1      voip  +16162081843                  2        Amerisave
# 2      voip  +15165658083                  2             None
# 3      voip  +12312656202                  2       2312656202
# 4      voip  +17022280222                  2      RR Partners
#
#   caller_number_source callee_number  caller_location callee_number_type  \
# 0                 None  +18287377552             None                  2
# 1             internal           300             None                  1
# 2             internal           300  Garden City  NY                  1
# 3             internal           226             None                  1
# 4             internal           208             None                  1
#
#   callee_number_source callee_location             callee_name direction  \
# 0             internal     Newland, NC                    None  outbound
# 1                 None            None  Main Auto Receptionist   inbound
# 2                 None            None  Main Auto Receptionist   inbound
# 3                 None            None          Jessica Osborn   inbound
# 4                 None            None        Jessica Caggiano   inbound
#
#   duration       result waiting_time             date_time              path  \
# 0        0  Call Cancel         None  2022-05-11T23:36:35Z              pstn
# 1        0    No Answer         None  2022-05-11T23:28:25Z  autoReceptionist
# 2        0    No Answer         None  2022-05-11T23:21:14Z  autoReceptionist
# 3        0    No Answer         None  2022-05-11T23:00:02Z              pstn
# 4        0    No Answer         None  2022-05-11T22:47:33Z              pstn
#
#   has_recording charge voice_mail_id has_voicemail  rate              call_id  \
# 0         false   None          None         false  None  7096626840318811841
# 1         false   None          None         false  None  7096624731490955678
# 2         false   None          None         false  None  7096622880360005894
# 3         false   None          None         false  None  7096617421447184140
# 4         false   None          None         false  None  7096614200270916926
#
#          owner_type                owner_id              owner_name  \
# 0              user  d9JiQ8qqTcCh6bfVo2YIYw         Nicole Thompson
# 1  autoReceptionist  fK99-uaJRnG8yW-b9B4-9g  Main Auto Receptionist
# 2  autoReceptionist  fK99-uaJRnG8yW-b9B4-9g  Main Auto Receptionist
# 3              user  1avZmyzLRzu2AInJp75T1Q          Jessica Osborn
# 4              user  bkasEu6zRz2YKurlHXnIqw        Jessica Caggiano
#
#   owner_extension_number caller_did_number caller_country_code  \
# 0                    255      +16167290255                   1
# 1                    300              None                   1
# 2                    300              None                   1
# 3                    226              None                   1
# 4                    208              None                   1
#
#   caller_country_iso_code callee_did_number callee_country_code  \
# 0                      US      +18287377552                   1
# 1                      US      +16162576300                   1
# 2                      US      +16162576300                   1
# 3                      US      +16162572026                   1
# 4                      US      +16162572008                   1
#
#   callee_country_iso_code answer_start_time         call_end_time
# 0                      US              None  2022-05-11T23:38:41Z
# 1                      US              None                  None
# 2                      US              None                  None
# 3                      US              None                  None
# 4                      US              None                  None

# %%
[
    ('page_size', 'int'),
    ('total_records', 'int'),
    ('from', 'date'),
    ('to', 'date'),
    ('caller_number_type', 'bigint'),
    ('callee_number_type', 'bigint'),
    ('duration', 'bigint'),
    ('waiting_time', 'bigint'),
    ('date_time', 'timestamp'),
    ('has_recording', 'boolean'),
    ('has_voicemail', 'boolean'),
    ('owner_extension_number', 'bigint'),
    ('call_end_time', 'timestamp')
]

# %%
bigint = [
    'caller_number_type',
    'callee_number_type',
    'duration',
    'waiting_time',
    
    'owner_extension_number'
]

_table.select(*bigint).limit(5).toPandas()
# Out:
#   caller_number_type callee_number_type duration waiting_time  \
# 0                  1                  2        0         None
# 1                  2                  1        0         None
# 2                  2                  1        0         None
# 3                  2                  1        0         None
# 4                  2                  1        0         None
#
#   owner_extension_number
# 0                    255
# 1                    300
# 2                    300
# 3                    226
# 4                    208

# %%
_table.where(col('owner_extension_number').startswith('0')).count()
# Out:
# 0

# %%
for column in bigint:
    # maximum = _table.selectExpr(f'max(cast({column} as bigint))').first()[0]
    maximum = _table.where(col(column).rlike('[^0-9]')).count()
    print(column, maximum)
# Out:
# caller_number_type 0
# callee_number_type 0
# duration 0
# waiting_time 0
# owner_extension_number 0

# %%
(
    _table
    .groupBy('has_recording', 'has_voicemail')
    .count()
    .show()
)
# Out:
# +-------------+-------------+-----+
# |has_recording|has_voicemail|count|
# +-------------+-------------+-----+
# |        false|         true|    1|
# |        false|        false| 2504|
# |        false|         null|   25|
# +-------------+-------------+-----+
